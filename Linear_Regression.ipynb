# %% [markdown]
# <a href="https://colab.research.google.com/github/Anvians/Google-Colab/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
readfile = pd.read_csv('Salary_Data.csv')
X = readfile.iloc[:, 0].values
y = readfile.iloc[:,-1].values

# %%
print(X)
# Out:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]

# %%
print(y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(X_train)
# Out:
# [[ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]
#  [ 2.9]
#  [ 5.1]
#  [ 3.2]
#  [ 4.5]
#  [ 8.2]
#  [ 6.8]
#  [ 1.3]
#  [10.5]
#  [ 3. ]
#  [ 2.2]
#  [ 5.9]
#  [ 6. ]
#  [ 3.7]
#  [ 3.2]
#  [ 9. ]
#  [ 2. ]
#  [ 1.1]
#  [ 7.1]
#  [ 4.9]
#  [ 4. ]]

# %%
print(y_train)
# Out:
# [112635.  55794.  83088. 101302.  56642.  66029.  64445.  61111. 113812.
#   91738.  46205. 121872.  60150.  39891.  81363.  93940.  57189.  54445.
#  105582.  43525.  39343.  98273.  67938.  56957.]

# %%
regression.predict(X_test)
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %%
plt.scatter(X_train, y_train ,color = 'red')
plt.plot(X_train, regression.predict(X_train), color = 'blue')
plt.title('Salery Vs Experience, (training set)')
plt.xlabel('Year of Experience')
plt.ylabel('Salery')
plt.show()

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, regression.predict(X_train),color = 'blue')
plt.title('Salery Vs Experience, (test set)')
plt.xlabel('Year of Experience')
plt.ylabel('Salery')
plt.show()
